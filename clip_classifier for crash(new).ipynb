# %% [markdown]
# ### Import the necessary Libraries

# %%
import ndjson
import json
import pickle
import os
import requests
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import cv2
import csv
import torch
import clip
from PIL import Image
from collections import deque
import datetime
import csv
from pathlib import Path
from ultralytics import YOLO
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import (
    classification_report, accuracy_score, roc_curve, auc, confusion_matrix, RocCurveDisplay, ConfusionMatrixDisplay
)
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_distances

# %% [markdown]
# ### Specify/update the paths of the data files

# %%
# path of the labelbox metadata file
META_DATA_PATH = 'Metadata/Archive 2/Export  project - Jumps_mad4tar - 7_24_2025.ndjson'

# directory to download the videos
VIDEOS_DIRECTORY = r"E:\VS Code Folders\i3d\videos"

IMAGES_DIRECTORY = 'crash_data2/images'

EMBEDDINGS_DIRECTORY = 'crash_data2/image_embeddings'

CSV_PATH = 'car_crash_data2.csv'

YOLO_MODEL_PATH = r"E:\VS Code Folders\yolo_training\runs\yolo11l.pt_2025-07-01_epochs_80_val_0.08\weights\best.pt"

# %% [markdown]
# ### Function to create directories if they don't exist

# %%
def check_path(video_path):
    if not os.path.exists(video_path):
        os.makedirs(video_path)
        print(f"Path {video_path} has been created successfully..!!")
    else:
        print(f"Path {video_path} already exists..!!")

# %%
check_path(VIDEOS_DIRECTORY)
check_path(IMAGES_DIRECTORY)
check_path(EMBEDDINGS_DIRECTORY)
# Out:
# Path E:\VS Code Folders\i3d\videos already exists..!!
# Path crash_data2/images has been created successfully..!!
# Path crash_data2/image_embeddings has been created successfully..!!

# %% [markdown]
# ### Specify the labels

# %%
LABELS = ['crash', 'no crash']

# %% [markdown]
# ### Function to download the videos if they don't already exist

# %%
def download_video(video_url, video_name, video_path):
    """
    Downloads a video from the given URL and saves it with the specified name in the videos folder.
    
    Args:
        video_url (str): The URL of the video to be downloaded.
        video_name (str): The name of the video file.
        videos_folder (str): The path to the folder where the video will be saved.
    """
    if os.path.exists(video_path):
        print(f"Video '{video_path}' already exists. Skipping download.")
        return
    
    try:
        response = requests.get(video_url, stream=True)
        if response.status_code == 200:
            with open(video_path, 'wb') as file:
                for chunk in response.iter_content(chunk_size=1024):
                    file.write(chunk)
            print(f"Video '{video_name}' downloaded successfully.")
        else:
            print(f"Error downloading video '{video_name}': {response.status_code}")
    except requests.exceptions.RequestException as e:
        print(f"Error downloading video '{video_name}': {e}")

# %% [markdown]
# ### Function to check if a path already exists

# %%
def check_if_path_exists(path):
    if os.path.exists(path):
        print(f"Path: {path} already exists..!!")
        return True

# %% [markdown]
# ### This function saves an image in the specified path if it already doesn't exist

# %%
def save_image(output_path, frame):
    if check_if_path_exists(output_path):
        print(f"Frame already exists at {output_path}")
        return False
    cv2.imwrite(output_path, frame)
    return True

# %% [markdown]
# ### This function uses OpenCV to extract a specified frame number from a video

# %%
def extract_frame_by_iteration(video_path, target_frame, output_path=None, save=False):
    if save and output_path and check_if_path_exists(output_path):
        print(f"Frame already exists at {output_path}")
        return cv2.imread(output_path)
    
    video = cv2.VideoCapture(video_path)
    if not video.isOpened():
        print("Error: Could not open video.")
        return None
    
    frame_count = 0
    success = True

    while success and frame_count <= target_frame:
        success, frame = video.read()
        frame_count += 1

        if frame_count == target_frame:
            if save and output_path:
                save_image(output_path, frame)
                print(f"Frame {target_frame} extracted and saved successfully.")
            else:
                print(f"Frame {target_frame} extracted successfully.")
            break

    if frame_count != target_frame:
        print(f"Error: Could not extract frame {target_frame}.")
        frame = None

    video.release()
    return frame

# Test
# extract_frame_by_iteration('videos/test.mp4', 105, 'images/test_105.png', True)

# %% [markdown]
# ### This function determines if the given frame index is a crash frame or a no crash frame index

# %%
def is_crash(frame_idx, ranges):
    return any(start <= frame_idx <= end for start, end in ranges)

# %% [markdown]
# ### This function runs YOLO on a frame and tells if there is a rally car in the frame or not

# %%
def run_yolo_on_frame(frame, model, conf_threshold=0.8):
    
    results = model(frame, verbose=False, classes=[0])[0]  # class 0 = car

    for box in results.boxes:
        if box.conf.item() > conf_threshold:
            return True  # At least one car detected

    return False  # No car detected above threshold

# %% [markdown]
# ### Function to load YOLO model

# %%
def load_yolo_model(path):
    """Load YOLO model from the specified path."""
    return YOLO(path, task='detect')

# %%
yolo_model = load_yolo_model(YOLO_MODEL_PATH)

# %%
# Check if file exists
file_exists = os.path.exists(CSV_PATH)
file_exists
# Out:
# False

# %%
# video_names = set(['vid_596.mp4', 'vid_1017.mp4', 'vid_587.mp4', 'vid_576.mp4', 'vid_624.mp4', 'vid_796.mp4', 'vid_705.mp4', 'vid_709.mp4', 'vid_575.mp4', 'vid_622.mp4', 'vid_847.mp4', 'vid_800.mp4', 'vid_863.mp4', 'vid_861.mp4', 'vid_600.mp4'])
video_names = None

# %% [markdown]
# ### This loop processes the metadata, goes through videos and creates the crash dataset
# #### It saves the images, names them with corresponding video names and labels
# #### Finally, it creates a CSV file that contains the following information: ["video", "image_label", "frame_number", "label"]

# %% [markdown]
# #### Specify every (nth) "crash" and "no crash" frames variables

# %%
CRASH_FRAMES_SAMPLING = 1 # Every single crash frame to be included in the dataset
NO_CRASH_FRAMES_SAMPLING = 15 # Every 15th no crash frame to be included in the dataset

# %%
# Check if file exists
file_exists = os.path.exists(CSV_PATH)

with open(CSV_PATH, 'a', newline='') as csvfile:  # 'a' mode = append
    writer = csv.writer(csvfile)
    
    if not file_exists:
        writer.writerow(["video", "image_label", "frame_number", "label"])  # Only write header if new file

    with open(META_DATA_PATH, 'r') as file:
        metadata = ndjson.load(file)

        for item in metadata:
            video_url = item['data_row']['row_data']
            video_name = item['data_row']['external_id']
            if video_names:
                if video_name not in video_names:
                    continue
            video_path = os.path.join(VIDEOS_DIRECTORY, video_name)

            frame_count = item['media_attributes']['frame_count']
            project_key = next(iter(item.get("projects", {})), None)
            if not project_key:
                continue

            frames = item["projects"][project_key]["labels"][0]["annotations"]["frames"]

            # 1. Collect all crash frames
            crash_list = []
            for frame_str, annotations in frames.items():
                if any(obj['value'] == 'crash' for obj in annotations['classifications']):
                    crash_list.append(int(frame_str))
            
            # if not crash_list:
            #     continue

            download_video(video_url, video_name, video_path)

            crash_list.sort()

            # 2. Form crash ranges
            crash_ranges = []
            if len(crash_list) % 2 == 0:
                for i in range(0, len(crash_list), 2):
                    start = crash_list[i]
                    end = crash_list[i + 1]
                    crash_ranges.append((start, end))

            # 3. Write crash frames
            for start, end in crash_ranges:
                for frame_number in range(start, end + 1, CRASH_FRAMES_SAMPLING):
                    image_label = f"{IMAGES_DIRECTORY}/{video_name[:-4]}_{frame_number}_1.png"
                    writer.writerow([video_name, image_label[19:], frame_number, 1])  # Label 1 = crash
                    extract_frame_by_iteration(video_path, frame_number, image_label, save=True)

            # 4. Sample every nth (no crash) frame
            for frame_number in range(1, frame_count, NO_CRASH_FRAMES_SAMPLING):
                if is_crash(frame_number, crash_ranges):
                    continue  # Already handled

                frame = extract_frame_by_iteration(video_path, frame_number)
                if frame is None:
                    continue

                image_label = f"{IMAGES_DIRECTORY}/{video_name[:-4]}_{frame_number}_0.png"
                if save_image(image_label, frame):
                    print(f"Frame {frame_number} saved successfully.")
                writer.writerow([video_name, image_label[19:], frame_number, 0])  # Label 0 = no crash
# Out:
# Video 'E:\VS Code Folders\i3d\videos\IMG_2599.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Frame 361 extracted successfully.
# Frame 361 saved successfully.
# Frame 381 extracted successfully.
# Frame 381 saved successfully.
# Frame 401 extracted successfully.
# Frame 401 saved successfully.
# Frame 421 extracted successfully.
# Frame 421 saved successfully.
# Frame 441 extracted successfully.
# Frame 441 saved successfully.
# Frame 461 extracted successfully.
# Frame 461 saved successfully.
# Frame 481 extracted successfully.
# Frame 481 saved successfully.
# Frame 501 extracted successfully.
# Frame 501 saved successfully.
# Frame 521 extracted successfully.
# Frame 521 saved successfully.
# Frame 541 extracted successfully.
# Frame 541 saved successfully.
# Frame 561 extracted successfully.
# Frame 561 saved successfully.
# Frame 581 extracted successfully.
# Frame 581 saved successfully.
# Frame 601 extracted successfully.
# Frame 601 saved successfully.
# Frame 621 extracted successfully.
# Frame 621 saved successfully.
# Frame 641 extracted successfully.
# Frame 641 saved successfully.
# Frame 661 extracted successfully.
# Frame 661 saved successfully.
# Frame 681 extracted successfully.
# Frame 681 saved successfully.
# Frame 701 extracted successfully.
# Frame 701 saved successfully.
# Frame 721 extracted successfully.
# Frame 721 saved successfully.
# Frame 741 extracted successfully.
# Frame 741 saved successfully.
# Frame 761 extracted successfully.
# Frame 761 saved successfully.
# Frame 781 extracted successfully.
# Frame 781 saved successfully.
# Frame 801 extracted successfully.
# Frame 801 saved successfully.
# Frame 821 extracted successfully.
# Frame 821 saved successfully.
# Frame 841 extracted successfully.
# Frame 841 saved successfully.
# Frame 861 extracted successfully.
# Frame 861 saved successfully.
# Frame 881 extracted successfully.
# Frame 881 saved successfully.
# Frame 901 extracted successfully.
# Frame 901 saved successfully.
# Frame 921 extracted successfully.
# Frame 921 saved successfully.
# Frame 941 extracted successfully.
# Frame 941 saved successfully.
# Frame 961 extracted successfully.
# Frame 961 saved successfully.
# Frame 981 extracted successfully.
# Frame 981 saved successfully.
# Frame 1001 extracted successfully.
# Frame 1001 saved successfully.
# Frame 1021 extracted successfully.
# Frame 1021 saved successfully.
# Frame 1041 extracted successfully.
# Frame 1041 saved successfully.
# Frame 1061 extracted successfully.
# Frame 1061 saved successfully.
# Frame 1081 extracted successfully.
# Frame 1081 saved successfully.
# Frame 1101 extracted successfully.
# Frame 1101 saved successfully.
# Frame 1121 extracted successfully.
# Frame 1121 saved successfully.
# Frame 1141 extracted successfully.
# Frame 1141 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_2612.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Frame 361 extracted successfully.
# Frame 361 saved successfully.
# Frame 381 extracted successfully.
# Frame 381 saved successfully.
# Frame 401 extracted successfully.
# Frame 401 saved successfully.
# Frame 421 extracted successfully.
# Frame 421 saved successfully.
# Frame 441 extracted successfully.
# Frame 441 saved successfully.
# Frame 461 extracted successfully.
# Frame 461 saved successfully.
# Frame 481 extracted successfully.
# Frame 481 saved successfully.
# Frame 501 extracted successfully.
# Frame 501 saved successfully.
# Frame 521 extracted successfully.
# Frame 521 saved successfully.
# Frame 541 extracted successfully.
# Frame 541 saved successfully.
# Frame 561 extracted successfully.
# Frame 561 saved successfully.
# Frame 581 extracted successfully.
# Frame 581 saved successfully.
# Frame 601 extracted successfully.
# Frame 601 saved successfully.
# Frame 621 extracted successfully.
# Frame 621 saved successfully.
# Frame 641 extracted successfully.
# Frame 641 saved successfully.
# Frame 661 extracted successfully.
# Frame 661 saved successfully.
# Frame 681 extracted successfully.
# Frame 681 saved successfully.
# Frame 701 extracted successfully.
# Frame 701 saved successfully.
# Frame 721 extracted successfully.
# Frame 721 saved successfully.
# Frame 741 extracted successfully.
# Frame 741 saved successfully.
# Frame 761 extracted successfully.
# Frame 761 saved successfully.
# Frame 781 extracted successfully.
# Frame 781 saved successfully.
# Frame 801 extracted successfully.
# Frame 801 saved successfully.
# Frame 821 extracted successfully.
# Frame 821 saved successfully.
# Frame 841 extracted successfully.
# Frame 841 saved successfully.
# Frame 861 extracted successfully.
# Frame 861 saved successfully.
# Frame 881 extracted successfully.
# Frame 881 saved successfully.
# Frame 901 extracted successfully.
# Frame 901 saved successfully.
# Frame 921 extracted successfully.
# Frame 921 saved successfully.
# Frame 941 extracted successfully.
# Frame 941 saved successfully.
# Frame 961 extracted successfully.
# Frame 961 saved successfully.
# Frame 981 extracted successfully.
# Frame 981 saved successfully.
# Frame 1001 extracted successfully.
# Frame 1001 saved successfully.
# Frame 1021 extracted successfully.
# Frame 1021 saved successfully.
# Frame 1041 extracted successfully.
# Frame 1041 saved successfully.
# Frame 1061 extracted successfully.
# Frame 1061 saved successfully.
# Frame 1081 extracted successfully.
# Frame 1081 saved successfully.
# Frame 1101 extracted successfully.
# Frame 1101 saved successfully.
# Frame 1121 extracted successfully.
# Frame 1121 saved successfully.
# Frame 1141 extracted successfully.
# Frame 1141 saved successfully.
# Frame 1161 extracted successfully.
# Frame 1161 saved successfully.
# Frame 1181 extracted successfully.
# Frame 1181 saved successfully.
# Frame 1201 extracted successfully.
# Frame 1201 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_2620.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Frame 361 extracted successfully.
# Frame 361 saved successfully.
# Frame 381 extracted successfully.
# Frame 381 saved successfully.
# Frame 401 extracted successfully.
# Frame 401 saved successfully.
# Frame 421 extracted successfully.
# Frame 421 saved successfully.
# Frame 441 extracted successfully.
# Frame 441 saved successfully.
# Frame 461 extracted successfully.
# Frame 461 saved successfully.
# Frame 481 extracted successfully.
# Frame 481 saved successfully.
# Frame 501 extracted successfully.
# Frame 501 saved successfully.
# Frame 521 extracted successfully.
# Frame 521 saved successfully.
# Frame 541 extracted successfully.
# Frame 541 saved successfully.
# Frame 561 extracted successfully.
# Frame 561 saved successfully.
# Frame 581 extracted successfully.
# Frame 581 saved successfully.
# Frame 601 extracted successfully.
# Frame 601 saved successfully.
# Frame 621 extracted successfully.
# Frame 621 saved successfully.
# Frame 641 extracted successfully.
# Frame 641 saved successfully.
# Frame 661 extracted successfully.
# Frame 661 saved successfully.
# Frame 681 extracted successfully.
# Frame 681 saved successfully.
# Frame 701 extracted successfully.
# Frame 701 saved successfully.
# Frame 721 extracted successfully.
# Frame 721 saved successfully.
# Frame 741 extracted successfully.
# Frame 741 saved successfully.
# Frame 761 extracted successfully.
# Frame 761 saved successfully.
# Frame 781 extracted successfully.
# Frame 781 saved successfully.
# Frame 801 extracted successfully.
# Frame 801 saved successfully.
# Frame 821 extracted successfully.
# Frame 821 saved successfully.
# Frame 841 extracted successfully.
# Frame 841 saved successfully.
# Frame 861 extracted successfully.
# Frame 861 saved successfully.
# Frame 881 extracted successfully.
# Frame 881 saved successfully.
# Frame 901 extracted successfully.
# Frame 901 saved successfully.
# Frame 921 extracted successfully.
# Frame 921 saved successfully.
# Frame 941 extracted successfully.
# Frame 941 saved successfully.
# Frame 961 extracted successfully.
# Frame 961 saved successfully.
# Frame 981 extracted successfully.
# Frame 981 saved successfully.
# Frame 1001 extracted successfully.
# Frame 1001 saved successfully.
# Frame 1021 extracted successfully.
# Frame 1021 saved successfully.
# Frame 1041 extracted successfully.
# Frame 1041 saved successfully.
# Frame 1061 extracted successfully.
# Frame 1061 saved successfully.
# Frame 1081 extracted successfully.
# Frame 1081 saved successfully.
# Frame 1101 extracted successfully.
# Frame 1101 saved successfully.
# Frame 1121 extracted successfully.
# Frame 1121 saved successfully.
# Frame 1141 extracted successfully.
# Frame 1141 saved successfully.
# Frame 1161 extracted successfully.
# Frame 1161 saved successfully.
# Frame 1181 extracted successfully.
# Frame 1181 saved successfully.
# Frame 1201 extracted successfully.
# Frame 1201 saved successfully.
# Frame 1221 extracted successfully.
# Frame 1221 saved successfully.
# Frame 1241 extracted successfully.
# Frame 1241 saved successfully.
# Frame 1261 extracted successfully.
# Frame 1261 saved successfully.
# Frame 1281 extracted successfully.
# Frame 1281 saved successfully.
# Frame 1301 extracted successfully.
# Frame 1301 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_2622.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Frame 361 extracted successfully.
# Frame 361 saved successfully.
# Frame 381 extracted successfully.
# Frame 381 saved successfully.
# Frame 401 extracted successfully.
# Frame 401 saved successfully.
# Frame 421 extracted successfully.
# Frame 421 saved successfully.
# Frame 441 extracted successfully.
# Frame 441 saved successfully.
# Frame 461 extracted successfully.
# Frame 461 saved successfully.
# Frame 481 extracted successfully.
# Frame 481 saved successfully.
# Frame 501 extracted successfully.
# Frame 501 saved successfully.
# Frame 521 extracted successfully.
# Frame 521 saved successfully.
# Frame 541 extracted successfully.
# Frame 541 saved successfully.
# Frame 561 extracted successfully.
# Frame 561 saved successfully.
# Frame 581 extracted successfully.
# Frame 581 saved successfully.
# Frame 601 extracted successfully.
# Frame 601 saved successfully.
# Frame 621 extracted successfully.
# Frame 621 saved successfully.
# Frame 641 extracted successfully.
# Frame 641 saved successfully.
# Frame 661 extracted successfully.
# Frame 661 saved successfully.
# Frame 681 extracted successfully.
# Frame 681 saved successfully.
# Frame 701 extracted successfully.
# Frame 701 saved successfully.
# Frame 721 extracted successfully.
# Frame 721 saved successfully.
# Frame 741 extracted successfully.
# Frame 741 saved successfully.
# Frame 761 extracted successfully.
# Frame 761 saved successfully.
# Frame 781 extracted successfully.
# Frame 781 saved successfully.
# Frame 801 extracted successfully.
# Frame 801 saved successfully.
# Frame 821 extracted successfully.
# Frame 821 saved successfully.
# Frame 841 extracted successfully.
# Frame 841 saved successfully.
# Frame 861 extracted successfully.
# Frame 861 saved successfully.
# Frame 881 extracted successfully.
# Frame 881 saved successfully.
# Frame 901 extracted successfully.
# Frame 901 saved successfully.
# Frame 921 extracted successfully.
# Frame 921 saved successfully.
# Frame 941 extracted successfully.
# Frame 941 saved successfully.
# Frame 961 extracted successfully.
# Frame 961 saved successfully.
# Frame 981 extracted successfully.
# Frame 981 saved successfully.
# Frame 1001 extracted successfully.
# Frame 1001 saved successfully.
# Frame 1021 extracted successfully.
# Frame 1021 saved successfully.
# Frame 1041 extracted successfully.
# Frame 1041 saved successfully.
# Frame 1061 extracted successfully.
# Frame 1061 saved successfully.
# Frame 1081 extracted successfully.
# Frame 1081 saved successfully.
# Frame 1101 extracted successfully.
# Frame 1101 saved successfully.
# Frame 1121 extracted successfully.
# Frame 1121 saved successfully.
# Frame 1141 extracted successfully.
# Frame 1141 saved successfully.
# Frame 1161 extracted successfully.
# Frame 1161 saved successfully.
# Frame 1181 extracted successfully.
# Frame 1181 saved successfully.
# Frame 1201 extracted successfully.
# Frame 1201 saved successfully.
# Frame 1221 extracted successfully.
# Frame 1221 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_5211.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Frame 361 extracted successfully.
# Frame 361 saved successfully.
# Frame 381 extracted successfully.
# Frame 381 saved successfully.
# Frame 401 extracted successfully.
# Frame 401 saved successfully.
# Frame 421 extracted successfully.
# Frame 421 saved successfully.
# Frame 441 extracted successfully.
# Frame 441 saved successfully.
# Frame 461 extracted successfully.
# Frame 461 saved successfully.
# Frame 481 extracted successfully.
# Frame 481 saved successfully.
# Frame 501 extracted successfully.
# Frame 501 saved successfully.
# Frame 521 extracted successfully.
# Frame 521 saved successfully.
# Frame 541 extracted successfully.
# Frame 541 saved successfully.
# Frame 561 extracted successfully.
# Frame 561 saved successfully.
# Frame 581 extracted successfully.
# Frame 581 saved successfully.
# Frame 601 extracted successfully.
# Frame 601 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_5213.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Frame 361 extracted successfully.
# Frame 361 saved successfully.
# Frame 381 extracted successfully.
# Frame 381 saved successfully.
# Frame 401 extracted successfully.
# Frame 401 saved successfully.
# Frame 421 extracted successfully.
# Frame 421 saved successfully.
# Frame 441 extracted successfully.
# Frame 441 saved successfully.
# Frame 461 extracted successfully.
# Frame 461 saved successfully.
# Frame 481 extracted successfully.
# Frame 481 saved successfully.
# Frame 501 extracted successfully.
# Frame 501 saved successfully.
# Frame 521 extracted successfully.
# Frame 521 saved successfully.
# Frame 541 extracted successfully.
# Frame 541 saved successfully.
# Frame 561 extracted successfully.
# Frame 561 saved successfully.
# Frame 581 extracted successfully.
# Frame 581 saved successfully.
# Frame 601 extracted successfully.
# Frame 601 saved successfully.
# Frame 621 extracted successfully.
# Frame 621 saved successfully.
# Frame 641 extracted successfully.
# Frame 641 saved successfully.
# Frame 661 extracted successfully.
# Frame 661 saved successfully.
# Frame 681 extracted successfully.
# Frame 681 saved successfully.
# Frame 701 extracted successfully.
# Frame 701 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_5218.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Frame 361 extracted successfully.
# Frame 361 saved successfully.
# Frame 381 extracted successfully.
# Frame 381 saved successfully.
# Frame 401 extracted successfully.
# Frame 401 saved successfully.
# Frame 421 extracted successfully.
# Frame 421 saved successfully.
# Frame 441 extracted successfully.
# Frame 441 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_5219.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Frame 361 extracted successfully.
# Frame 361 saved successfully.
# Frame 381 extracted successfully.
# Frame 381 saved successfully.
# Frame 401 extracted successfully.
# Frame 401 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_5224.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_5284.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_5287.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Frame 361 extracted successfully.
# Frame 361 saved successfully.
# Frame 381 extracted successfully.
# Frame 381 saved successfully.
# Frame 401 extracted successfully.
# Frame 401 saved successfully.
# Frame 421 extracted successfully.
# Frame 421 saved successfully.
# Frame 441 extracted successfully.
# Frame 441 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_5288.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Frame 361 extracted successfully.
# Frame 361 saved successfully.
# Frame 381 extracted successfully.
# Frame 381 saved successfully.
# Frame 401 extracted successfully.
# Frame 401 saved successfully.
# Frame 421 extracted successfully.
# Frame 421 saved successfully.
# Frame 441 extracted successfully.
# Frame 441 saved successfully.
# Frame 461 extracted successfully.
# Frame 461 saved successfully.
# Frame 481 extracted successfully.
# Frame 481 saved successfully.
# Frame 501 extracted successfully.
# Frame 501 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_5293.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_5294.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_5310.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_5313.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_5768.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Video 'IMG_5769.mp4' downloaded successfully.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Frame 361 extracted successfully.
# Frame 361 saved successfully.
# Frame 381 extracted successfully.
# Frame 381 saved successfully.
# Frame 401 extracted successfully.
# Frame 401 saved successfully.
# Frame 421 extracted successfully.
# Frame 421 saved successfully.
# Frame 441 extracted successfully.
# Frame 441 saved successfully.
# Frame 461 extracted successfully.
# Frame 461 saved successfully.
# Frame 481 extracted successfully.
# Frame 481 saved successfully.
# Frame 501 extracted successfully.
# Frame 501 saved successfully.
# Frame 521 extracted successfully.
# Frame 521 saved successfully.
# Frame 541 extracted successfully.
# Frame 541 saved successfully.
# Frame 561 extracted successfully.
# Frame 561 saved successfully.
# Frame 581 extracted successfully.
# Frame 581 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_5770.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_5773.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_5783.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_5787.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_6400.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Frame 361 extracted successfully.
# Frame 361 saved successfully.
# Frame 381 extracted successfully.
# Frame 381 saved successfully.
# Frame 401 extracted successfully.
# Frame 401 saved successfully.
# Frame 421 extracted successfully.
# Frame 421 saved successfully.
# Frame 441 extracted successfully.
# Frame 441 saved successfully.
# Frame 461 extracted successfully.
# Frame 461 saved successfully.
# Frame 481 extracted successfully.
# Frame 481 saved successfully.
# Frame 501 extracted successfully.
# Frame 501 saved successfully.
# Frame 521 extracted successfully.
# Frame 521 saved successfully.
# Frame 541 extracted successfully.
# Frame 541 saved successfully.
# Frame 561 extracted successfully.
# Frame 561 saved successfully.
# Frame 581 extracted successfully.
# Frame 581 saved successfully.
# Frame 601 extracted successfully.
# Frame 601 saved successfully.
# Frame 621 extracted successfully.
# Frame 621 saved successfully.
# Frame 641 extracted successfully.
# Frame 641 saved successfully.
# Frame 661 extracted successfully.
# Frame 661 saved successfully.
# Frame 681 extracted successfully.
# Frame 681 saved successfully.
# Frame 701 extracted successfully.
# Frame 701 saved successfully.
# Frame 721 extracted successfully.
# Frame 721 saved successfully.
# Frame 741 extracted successfully.
# Frame 741 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_8366.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Frame 361 extracted successfully.
# Frame 361 saved successfully.
# Frame 381 extracted successfully.
# Frame 381 saved successfully.
# Frame 401 extracted successfully.
# Frame 401 saved successfully.
# Frame 421 extracted successfully.
# Frame 421 saved successfully.
# Frame 441 extracted successfully.
# Frame 441 saved successfully.
# Frame 461 extracted successfully.
# Frame 461 saved successfully.
# Frame 481 extracted successfully.
# Frame 481 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_8367.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Frame 361 extracted successfully.
# Frame 361 saved successfully.
# Frame 381 extracted successfully.
# Frame 381 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_8369.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Frame 361 extracted successfully.
# Frame 361 saved successfully.
# Frame 381 extracted successfully.
# Frame 381 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_8370.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Frame 361 extracted successfully.
# Frame 361 saved successfully.
# Frame 381 extracted successfully.
# Frame 381 saved successfully.
# Frame 401 extracted successfully.
# ...
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Frame 361 extracted successfully.
# Frame 361 saved successfully.
# Frame 381 extracted successfully.
# Frame 381 saved successfully.
# Frame 401 extracted successfully.
# Frame 401 saved successfully.
# Frame 421 extracted successfully.
# Frame 421 saved successfully.
# Frame 441 extracted successfully.
# Frame 441 saved successfully.
# Frame 461 extracted successfully.
# Frame 461 saved successfully.
# Frame 481 extracted successfully.
# Frame 481 saved successfully.
# Frame 501 extracted successfully.
# Frame 501 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_8413.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Frame 361 extracted successfully.
# Frame 361 saved successfully.
# Frame 381 extracted successfully.
# Frame 381 saved successfully.
# Frame 401 extracted successfully.
# Frame 401 saved successfully.
# Frame 421 extracted successfully.
# Frame 421 saved successfully.
# Frame 441 extracted successfully.
# Frame 441 saved successfully.
# Frame 461 extracted successfully.
# Frame 461 saved successfully.
# Frame 481 extracted successfully.
# Frame 481 saved successfully.
# Frame 501 extracted successfully.
# Frame 501 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_8414.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Frame 361 extracted successfully.
# Frame 361 saved successfully.
# Frame 381 extracted successfully.
# Frame 381 saved successfully.
# Frame 401 extracted successfully.
# Frame 401 saved successfully.
# Frame 421 extracted successfully.
# Frame 421 saved successfully.
# Frame 441 extracted successfully.
# Frame 441 saved successfully.
# Frame 461 extracted successfully.
# Frame 461 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_8415.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Frame 361 extracted successfully.
# Frame 361 saved successfully.
# Frame 381 extracted successfully.
# Frame 381 saved successfully.
# Frame 401 extracted successfully.
# Frame 401 saved successfully.
# Frame 421 extracted successfully.
# Frame 421 saved successfully.
# Frame 441 extracted successfully.
# Frame 441 saved successfully.
# Frame 461 extracted successfully.
# Frame 461 saved successfully.
# Frame 481 extracted successfully.
# Frame 481 saved successfully.
# Frame 501 extracted successfully.
# Frame 501 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_9071.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_9072.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_9073.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Frame 361 extracted successfully.
# Frame 361 saved successfully.
# Frame 381 extracted successfully.
# Frame 381 saved successfully.
# Frame 401 extracted successfully.
# Frame 401 saved successfully.
# Frame 421 extracted successfully.
# Frame 421 saved successfully.
# Frame 441 extracted successfully.
# Frame 441 saved successfully.
# Frame 461 extracted successfully.
# Frame 461 saved successfully.
# Frame 481 extracted successfully.
# Frame 481 saved successfully.
# Frame 501 extracted successfully.
# Frame 501 saved successfully.
# Frame 521 extracted successfully.
# Frame 521 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_9074.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_9078.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_9085.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_9086.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_9087.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.
# Frame 241 extracted successfully.
# Frame 241 saved successfully.
# Frame 261 extracted successfully.
# Frame 261 saved successfully.
# Frame 281 extracted successfully.
# Frame 281 saved successfully.
# Frame 301 extracted successfully.
# Frame 301 saved successfully.
# Frame 321 extracted successfully.
# Frame 321 saved successfully.
# Frame 341 extracted successfully.
# Frame 341 saved successfully.
# Frame 361 extracted successfully.
# Frame 361 saved successfully.
# Frame 381 extracted successfully.
# Frame 381 saved successfully.
# Frame 401 extracted successfully.
# Frame 401 saved successfully.
# Frame 421 extracted successfully.
# Frame 421 saved successfully.
# Frame 441 extracted successfully.
# Frame 441 saved successfully.
# Frame 461 extracted successfully.
# Frame 461 saved successfully.
# Frame 481 extracted successfully.
# Frame 481 saved successfully.
# Frame 501 extracted successfully.
# Frame 501 saved successfully.
# Video 'E:\VS Code Folders\i3d\videos\IMG_9088.mp4' already exists. Skipping download.
# Frame 1 extracted successfully.
# Frame 1 saved successfully.
# Frame 21 extracted successfully.
# Frame 21 saved successfully.
# Frame 41 extracted successfully.
# Frame 41 saved successfully.
# Frame 61 extracted successfully.
# Frame 61 saved successfully.
# Frame 81 extracted successfully.
# Frame 81 saved successfully.
# Frame 101 extracted successfully.
# Frame 101 saved successfully.
# Frame 121 extracted successfully.
# Frame 121 saved successfully.
# Frame 141 extracted successfully.
# Frame 141 saved successfully.
# Frame 161 extracted successfully.
# Frame 161 saved successfully.
# Frame 181 extracted successfully.
# Frame 181 saved successfully.
# Frame 201 extracted successfully.
# Frame 201 saved successfully.
# Frame 221 extracted successfully.
# Frame 221 saved successfully.

# %% [markdown]
# ### Remove duplicates (if any) present in the CSV file

# %%
unique_rows = set()
deduplicated_rows = []

with open(CSV_PATH, 'r') as file:
    reader = csv.DictReader(file)
    fieldnames = reader.fieldnames  # Preserve headers

    for row in reader:
        row_tuple = tuple(row.items())  # Convert to a hashable type
        if row_tuple not in unique_rows:
            unique_rows.add(row_tuple)
            deduplicated_rows.append(row)

# Optional: Overwrite original CSV with deduplicated data
with open(CSV_PATH, 'w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(deduplicated_rows)

# %% [markdown]
# ### Count the number of "crash" and "no crash" frames

# %%
crash_count = 0
no_crash_count = 0

with open(CSV_PATH, 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        label = row['label'].strip()
        if label == '1':
            crash_count += 1
        elif label == '0':
            no_crash_count += 1

print(f"Crash frames (label=1): {crash_count}")
print(f"No Crash frames (label=0): {no_crash_count}")
# Out:
# Crash frames (label=1): 2672
# No Crash frames (label=0): 5528

# %% [markdown]
# ### Function to Load the CLIP model for embeddings generation

# %%
def load_clip_model():
    print("Loading OpenAI CLIP...")
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model, preprocess = clip.load("ViT-L/14@336px", device=device)
    model.eval()
    print(f"Model loaded on {device}.")
    return model, preprocess, device

# %%
clip_model, preprocess, device = load_clip_model()
# Out:
# Loading OpenAI CLIP...
# Model loaded on cuda.

# %% [markdown]
# ### Go through all the images saved, create each image's embeddings and save them

# %%
images = os.listdir(IMAGES_DIRECTORY)

for image_name in images:
    image_path = os.path.join(IMAGES_DIRECTORY, image_name)

    # Skip non-image files
    if not image_name.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.webp')):
        continue

    emb_path = os.path.join(EMBEDDINGS_DIRECTORY, os.path.splitext(image_name)[0] + ".npy")

    if check_if_path_exists(emb_path):
        continue
    # Load and preprocess image
    bgr_img = cv2.imread(image_path)
    if bgr_img is None:
        print(f"Warning: Failed to load {image_name}")
        continue

    pil_image = Image.fromarray(cv2.cvtColor(bgr_img, cv2.COLOR_BGR2RGB))
    img_tensor = preprocess(pil_image).unsqueeze(0).to(device)

    # Encode image with CLIP
    with torch.no_grad():
        img_feat = clip_model.encode_image(img_tensor)
        img_feat = img_feat / img_feat.norm(dim=-1, keepdim=True)

    # Convert to numpy and save
    embedding = img_feat.squeeze(0).cpu().numpy()
    np.save(emb_path, embedding)

# %% [markdown]
# ### Plot the T-SNE using the embeddings and the labels

# %%
embeddings = []
labels = []
label_names = []

with open(CSV_PATH, 'r') as f:
    reader = csv.DictReader(f)
    for row in reader:
        image_name = row['image_label']  # column name as in the CSV
        label = int(row['label'])
        embedding_file = os.path.splitext(image_name)[0] + '.npy'
        embedding_path = os.path.join(EMBEDDINGS_DIRECTORY, embedding_file)
        if os.path.exists(embedding_path):
            emb = np.load(embedding_path)
            embeddings.append(emb)
            labels.append(label)
            label_names.append(image_name)
        else:
            print(f"Missing embedding for {embedding_path}")

embeddings = np.array(embeddings)
labels = np.array(labels)

# t-SNE
tsne = TSNE(n_components=2, random_state=42, perplexity=30)
embeddings_2d = tsne.fit_transform(embeddings)

# Plot
plt.figure(figsize=(10, 8))
colors = ['red', 'blue']
for label_value, color, label_str in zip([0, 1], colors, LABELS):
    idx = labels == label_value
    plt.scatter(embeddings_2d[idx, 0], embeddings_2d[idx, 1], c=color, label=label_str, alpha=0.6, s=10)

plt.legend()
plt.title('t-SNE of CLIP Embeddings: crash vs no crash')
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.show()

# %% [markdown]
# ### PCA visualization

# %%
pca = PCA(n_components=2)
embeddings_2d = pca.fit_transform(embeddings)

# Plot (reuse existing code)
plt.figure(figsize=(10, 8))
for label_value, color, label_str in zip([0, 1], colors, LABELS):
    idx = labels == label_value
    plt.scatter(embeddings_2d[idx, 0], embeddings_2d[idx, 1], c=color, label=label_str, alpha=0.6, s=10)

plt.legend()
plt.title('PCA of CLIP Embeddings: crash vs no crash')
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.show()

# %% [markdown]
# ### Heatmap

# %%
dist_matrix = cosine_distances(embeddings)
sns.heatmap(dist_matrix, cmap='viridis')
plt.title('Cosine Distance Heatmap of Embeddings')
plt.show()

# %% [markdown]
# ### Load the CSV file and map all the images to the video they belong to

# %%
# 1. Read CSV and group by video
video_to_rows = {}
with open(CSV_PATH, 'r') as f:
    reader = csv.DictReader(f)
    for row in reader:
        video = row['video']
        if video not in video_to_rows:
            video_to_rows[video] = []
        video_to_rows[video].append(row)

# %% [markdown]
# ### Split the data (by videos) in training and validation sets

# %%
# 2. Split videos into train/val
videos = list(video_to_rows.keys())
train_videos, val_videos = train_test_split(videos, test_size=0.1, random_state=37)
print(f"Train videos: {len(train_videos)}")
print(f"Validation videos: {len(val_videos)}")
# Out:
# Train videos: 259
# Validation videos: 29

# %% [markdown]
# ### Function to load the embeddings and the corresponding labels

# %%
def load_data(video_list):
    X, y = [], []
    for video in video_list:
        for row in video_to_rows[video]:
            image_name = row['image_label']
            label = int(row['label'])
            embedding_file = os.path.splitext(image_name)[0] + '.npy'
            embedding_path = os.path.join(EMBEDDINGS_DIRECTORY, embedding_file)
            if os.path.exists(embedding_path):
                emb = np.load(embedding_path)
                X.append(emb)
                y.append(label)
    return np.array(X), np.array(y)

# %%
# 3. Load embeddings and labels
X_train, y_train = load_data(train_videos)
X_val, y_val = load_data(val_videos)

print(f"Train samples: {len(y_train)}, Val samples: {len(y_val)}")
# Out:
# Train samples: 7279, Val samples: 921

# %% [markdown]
# ### Train on multiple classifiers

# %%
# Define classifiers
classifiers = {
    "Logistic Regression": LogisticRegression(max_iter=1500),
    "Linear SVM": LinearSVC(max_iter=10000),
    "Kernel SVM (RBF)": SVC(kernel='rbf', probability=True),
    "Polynomial SVM (degree 3)": SVC(kernel='poly', degree=3, probability=True),
    "Sigmoid SVM": SVC(kernel='sigmoid', probability=True),
    "Random Forest": RandomForestClassifier(n_estimators=200),
    # "Gradient Boosting": GradientBoostingClassifier(),
    "K-Nearest Neighbors": KNeighborsClassifier(n_neighbors=9)
}

results = {}

for name, clf in classifiers.items():
    print(f"\nTraining {name}...")
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_val)
    acc = accuracy_score(y_val, y_pred)
    print(f"Validation Accuracy: {acc:.4f}")
    print(classification_report(y_val, y_pred, target_names=['no crash', 'crash']))
    results[name] = acc

    # ROC Curve
    plt.figure(figsize=(6, 5))
    if hasattr(clf, "predict_proba"):
        y_score = clf.predict_proba(X_val)[:, 1]
    else:
        # For LinearSVC, use decision_function
        y_score = clf.decision_function(X_val)
    fpr, tpr, _ = roc_curve(y_val, y_score)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve: {name}')
    plt.legend(loc="lower right")
    plt.show()

    # Confusion Matrix
    cm = confusion_matrix(y_val, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['no crash', 'crash'])
    disp.plot(cmap=plt.cm.Blues)
    plt.title(f'Confusion Matrix: {name}')
    plt.show()


# Print summary
print("\nSummary of Validation Accuracies:")
for name, acc in results.items():
    print(f"{name}: {acc:.4f}")
# Out:
# Training Logistic Regression...
# Validation Accuracy: 0.8719
#               precision    recall  f1-score   support
#
#     no crash       0.83      0.98      0.90       519
#        crash       0.96      0.73      0.83       402
#
#     accuracy                           0.87       921
#    macro avg       0.90      0.86      0.86       921
# weighted avg       0.89      0.87      0.87       921
# Training Linear SVM...
# Validation Accuracy: 0.8415
#               precision    recall  f1-score   support
#
#     no crash       0.79      0.99      0.88       519
#        crash       0.98      0.65      0.78       402
#
#     accuracy                           0.84       921
#    macro avg       0.88      0.82      0.83       921
# weighted avg       0.87      0.84      0.83       921
# Training Kernel SVM (RBF)...
# Validation Accuracy: 0.8664
#               precision    recall  f1-score   support
#
#     no crash       0.82      0.98      0.89       519
#        crash       0.96      0.72      0.83       402
#
#     accuracy                           0.87       921
#    macro avg       0.89      0.85      0.86       921
# weighted avg       0.88      0.87      0.86       921
# Training Polynomial SVM (degree 3)...
# Validation Accuracy: 0.8643
#               precision    recall  f1-score   support
#
#     no crash       0.81      0.99      0.89       519
#        crash       0.98      0.71      0.82       402
#
#     accuracy                           0.86       921
#    macro avg       0.89      0.85      0.86       921
# weighted avg       0.88      0.86      0.86       921
# Training Sigmoid SVM...
# Validation Accuracy: 0.8599
#               precision    recall  f1-score   support
#
#     no crash       0.82      0.97      0.89       519
#        crash       0.95      0.72      0.82       402
#
#     accuracy                           0.86       921
#    macro avg       0.88      0.84      0.85       921
# weighted avg       0.87      0.86      0.86       921
# Training Random Forest...
# Validation Accuracy: 0.8458
#               precision    recall  f1-score   support
#
#     no crash       0.79      0.99      0.88       519
#        crash       0.99      0.66      0.79       402
#
#     accuracy                           0.85       921
#    macro avg       0.89      0.82      0.83       921
# weighted avg       0.87      0.85      0.84       921
# Training K-Nearest Neighbors...
# Validation Accuracy: 0.9218
#               precision    recall  f1-score   support
#
#     no crash       0.92      0.95      0.93       519
#        crash       0.93      0.89      0.91       402
#
#     accuracy                           0.92       921
#    macro avg       0.92      0.92      0.92       921
# weighted avg       0.92      0.92      0.92       921
# Summary of Validation Accuracies:
# Logistic Regression: 0.8719
# Linear SVM: 0.8415
# Kernel SVM (RBF): 0.8664
# Polynomial SVM (degree 3): 0.8643
# Sigmoid SVM: 0.8599
# Random Forest: 0.8458
# K-Nearest Neighbors: 0.9218

# %% [markdown]
# ### Try out the best performing classifier

# %%
clf = SVC(kernel='poly', degree=3, probability=True)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_val)
acc = accuracy_score(y_val, y_pred)
print(f"Validation Accuracy: {acc:.4f}")
print(classification_report(y_val, y_pred, target_names=['no crash', 'crash']))
# Out:
# Validation Accuracy: 0.8643
#               precision    recall  f1-score   support
#
#     no crash       0.81      0.99      0.89       519
#        crash       0.98      0.71      0.82       402
#
#     accuracy                           0.86       921
#    macro avg       0.89      0.85      0.86       921
# weighted avg       0.88      0.86      0.86       921

# %% [markdown]
# ### Specify the model name

# %%
MODEL_NAME = 'classifier.pkl'

# %% [markdown]
# ### Save the model

# %%
with open(MODEL_NAME, "wb") as f:
    pickle.dump(clf, f)

print(f"Model saved as {MODEL_NAME}")

# %% [markdown]
# ### Perform Inference on Videos (without smoothing)

# %%
# Video input/output paths
video_path = r"C:\Users\littl\Downloads\Rally_Car_Crash_Video_Created.mp4"
video_name = os.path.basename(video_path)
output_video_path = f"crashes/{video_name}"

# Open video
cap = cv2.VideoCapture(video_path)
fps = cap.get(cv2.CAP_PROP_FPS)
width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Writer to save output
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

frame_count = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    frame_count += 1

    # Convert frame to RGB and PIL
    pil_image = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    img_tensor = preprocess(pil_image).unsqueeze(0).to(device)

    # Get CLIP embedding
    with torch.no_grad():
        img_feat = clip_model.encode_image(img_tensor)
        img_feat = img_feat / img_feat.norm(dim=-1, keepdim=True)

    # Predict using SVM
    embedding_np = img_feat.squeeze(0).cpu().numpy().reshape(1, -1)
    pred = clf.predict(embedding_np)[0]
    prob = clf.predict_proba(embedding_np)[0].max()

    # Overlay prediction on frame
    label_text = f"{'crash' if pred == 1 else 'no crash'} ({prob:.2f})"
    cv2.putText(frame, label_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 
                1, (0, 255, 0) if pred == 1 else (0, 0, 255), 2)

    # Write frame to output video
    out.write(frame)

    # (Optional) Show live preview
    # cv2.imshow('Prediction', frame)
    # if cv2.waitKey(1) & 0xFF == ord('q'):
    #     break

cap.release()
out.release()
cv2.destroyAllWindows()
print("Done! Saved to:", output_video_path)
# Out:
# Done! Saved to: crashes/Rally_Car_Crash_Video_Created.mp4

# %% [markdown]
# ### Zero-shot crash classification using CLIP on the validation set

# %%
CRASH_PROMPTS = [
        "a photo of a rally car crashing into a barrier",
        "an image of a rally car colliding with a tree",
        "a picture of a rally car crashing into a ditch",
        "an image of a rally car losing control and rolling over",
        "a photo of a rally car veering off the road and crashing",
        "a picture of a rally car skidding and hitting a wall",
        "an image of a rally car spinning out and crashing",
        "a picture of a rally car hitting another vehicle",
        "a photo of a rally car crashing during a sharp turn",
        "an image of a rally car flipping after hitting a bump",
        "a picture of a rally car colliding with a pole",
        "a photo of a rally car crashing into a fence",
        "a picture of a rally car falling off a cliff",
        "an image of a rally car crashing into a spectator area",
        "a photo of a rally car hitting a rock and flipping",
        "a picture of a rally car crashing into a house",
        "an image of a rally car crashing into a bridge support",
        "a photo of a rally car exploding after a high-speed crash",
        "a picture of a rally car sliding into a body of water",
        "an image of a rally car catching fire after a crash"
]

NO_CRASH_PROMPTS = [
    "a photo of a rally car driving smoothly on a gravel road",
    "an image of a rally car drifting around a bend without crashing",
    "a picture of a rally car maintaining control at high speed",
    "an image of a rally car driving through a forest trail",
    "a photo of a rally car driving through shallow water",
    "a picture of a rally car passing a checkpoint on the track",
    "an image of a rally car following a race path without issues",
    "a picture of a rally car overtaking another car safely",
    "a photo of a rally car driving along a mountain road",
    "an image of a rally car navigating tight corners successfully",
    "a picture of a rally car accelerating on a straight stretch",
    "a photo of a rally car slowing down before a turn",
    "an image of a rally car going over a jump and landing safely",
    "a picture of a rally car calmly cruising on a dirt road",
    "a photo of a rally car on a tarmac rally stage"
]

all_prompts = CRASH_PROMPTS + NO_CRASH_PROMPTS
crash_count = len(CRASH_PROMPTS)

# 2. Encode text prompts
with torch.no_grad():
    text_tokens = clip.tokenize(all_prompts).to(device)
    text_features = clip_model.encode_text(text_tokens)
    text_features /= text_features.norm(dim=-1, keepdim=True)
    text_features = text_features.float()

# 3. Classify each validation embedding
y_pred_zeroshot = []
y_score_zeroshot = []

for emb in X_val:
    img_feat = torch.tensor(emb, dtype=torch.float32, device=device).unsqueeze(0)
    img_feat /= img_feat.norm(dim=-1, keepdim=True)
    with torch.no_grad():
        logits = 100.0 * img_feat @ text_features.T
        probs = logits.softmax(dim=-1).cpu().numpy()[0]
    prob_on = probs[:crash_count].sum()
    prob_off = probs[crash_count:].sum()
    y_pred_zeroshot.append(1 if prob_on > prob_off else 0)
    y_score_zeroshot.append(prob_on)  # Use prob_on as the "score" for ROC

y_pred_zeroshot = np.array(y_pred_zeroshot)
y_score_zeroshot = np.array(y_score_zeroshot)

# 4. Print metrics
print("Zero-Shot CLIP Classifier Results:")
print("Validation Accuracy:", accuracy_score(y_val, y_pred_zeroshot))
print(classification_report(y_val, y_pred_zeroshot, target_names=['no crash', 'crash']))

# 5. ROC Curve
fpr, tpr, _ = roc_curve(y_val, y_score_zeroshot)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve: Zero-Shot CLIP')
plt.legend(loc="lower right")
plt.show()

# 6. Confusion Matrix
cm = confusion_matrix(y_val, y_pred_zeroshot)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['no crash', 'crash'])
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix: Zero-Shot CLIP')
plt.show()
# Out:
# Zero-Shot CLIP Classifier Results:
# Validation Accuracy: 0.7392996108949417
#               precision    recall  f1-score   support
#
#     no crash       0.89      0.52      0.65       244
#        crash       0.68      0.94      0.79       270
#
#     accuracy                           0.74       514
#    macro avg       0.79      0.73      0.72       514
# weighted avg       0.78      0.74      0.73       514
